# %% [markdown]
# # Pakiety Matematyczne - wykład 2

# %% [markdown]
# <img src="DzienDobry.jpg">

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
# %matplotlib inline

# %%
x = np.linspace(1/(2*math.e), math.e**2+1)
y = np.log(x)

plt.plot(x, y)
plt.show()

# %%
y2 = np.log(1/x)

#plt.plot(x,y,x,y2,label=['1','2'])  # legenda nie działa
plt.plot(x, y, label='ln(x)')
plt.plot(x, y2, label='$\\ln(\\frac{1}{x})$')
plt.legend(loc='right')
plt.show()

# %%
help(plt.plot)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args, scalex=True, scaley=True, data=None, **kwargs)
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %%
plt.plot(x, y, 'r>', linestyle='--', label='ln(x)')
plt.plot(x, y2, 'g3',label='ln(1/x)')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %%
plt.plot(x, y, label='ln(x)')
plt.plot(x, y2,label='$\\ln(\\frac{1}{x})$')
plt.legend(loc='best')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Przykład')
plt.grid()
plt.xticks([0, 1/math.e,1, math.e,2*math.e,math.e**2],\
          ['$0$','$\\frac{1}{e}$','$1$', '$e$','$2e$','$e^2$'])
plt.yticks([-2,-1,0,1,2])
plt.show()

# %%
help(plt.grid)
# Out:
# Help on function grid in module matplotlib.pyplot:
#
# grid(b=None, which='major', axis='both', **kwargs)
#     Configure the grid lines.
#
#     Parameters
#     ----------
#     b : bool or None, optional
#         Whether to show the grid lines. If any *kwargs* are supplied,
#         it is assumed you want the grid on and *b* will be set to True.
#
#         If *b* is *None* and there are no *kwargs*, this toggles the
#         visibility of the lines.
#
#     which : {'major', 'minor', 'both'}, optional
#         The grid lines to apply the changes on.
#
#     axis : {'both', 'x', 'y'}, optional
#         The axis to apply the changes on.
#
#     **kwargs : `.Line2D` properties
#         Define the line properties of the grid, e.g.::
#
#             grid(color='r', linestyle='-', linewidth=2)
#
#         Valid keyword arguments are:
#
#         Properties:
#         agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array
# ...

# %%
help(plt.xticks)
# Out:
# Help on function xticks in module matplotlib.pyplot:
#
# xticks(ticks=None, labels=None, **kwargs)
#     Get or set the current tick locations and labels of the x-axis.
#
#     Pass no arguments to return the current values without modifying them.
#
#     Parameters
#     ----------
#     ticks : array-like, optional
#         The list of xtick locations.  Passing an empty list removes all xticks.
#     labels : array-like, optional
#         The labels to place at the given *ticks* locations.  This argument can
#         only be passed if *ticks* is passed as well.
#     **kwargs
#         `.Text` properties can be used to control the appearance of the labels.
#
#     Returns
#     -------
#     locs
#         The list of xtick locations.
#     labels
#         The list of xlabel `.Text` objects.
#
#     Notes
#     -----
#     Calling this function with no arguments (e.g. ``xticks()``) is the pyplot
#     equivalent of calling `~.Axes.get_xticks` and `~.Axes.get_xticklabels` on
# ...

# %%
#plt.style.use('default')
#plt.style.use('ggplot')
plt.style.use('dark_background')
# others style references you can find on matplotlib gallery website

x = np.linspace(1/(2*math.e), math.e**2+1)
y = np.log(x)
y2 = np.log(1/x)

plt.plot(x, y, label='ln(x)')
plt.plot(x, y2, label='ln(1/x)')
plt.legend(loc='best')
plt.show()

# %%
plt.style.use('default')
x = np.linspace(0, 2.5)
y3 = np.exp(x)

plt.plot(x, y3, label='exp(x)')
plt.plot(x, 3*x+1,label='3x+1')
plt.fill_between(x, y3, 3*x+1, where=y3<3*x+1, color='green', alpha=0.2)


plt.legend(loc='best')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Przykład')
plt.show()

# %%
x = np.random.random(10)
y = np.random.random(10)

size = 1000*(x+y)


plt.scatter(x, y, c='red', s=size, marker='*')
plt.show()

# %%
x = np.linspace(-5, 5, 21)
y = np.linspace(-5, 5, 21)

X, Y = np.meshgrid(x, y)
Z = X**2 - Y**2 

plt.contourf(X, Y, Z, levels=10)
plt.colorbar()
plt.show()
#print(X)

# %%
x = np.linspace(-5, 5, 20)
y = np.linspace(-5, 5, 20)

X, Y = np.meshgrid(x, y)
Z = X**2 + Y**2 

plt.contourf(X, Y, Z, levels=20, cmap='Reds')
plt.colorbar()
plt.show()

# %%
x = np.linspace(1/(2*math.e), math.e**2+1)
y = np.log(x)
y2 = np.log(2*x)
y3 = np.log(1/x)

plt.subplot(2, 3, 1) # upper left
plt.plot(x, y, label='ln(x)')
plt.plot(x, y2, label='ln(2x)')
plt.legend(loc='best')

plt.subplot(2, 3, 2) # upper right
plt.plot(x, y, label='ln(x)')
plt.plot(x, y3,label='ln(1/x)')
plt.legend(loc='best')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Przykład')
plt.grid(True)
plt.xticks([1/math.e,1,math.e,2*math.e,math.e**2],\
          ['$\\frac{1}{e}$','$1$', '$e$','$2e$','$e^2$'])
plt.yticks([-2,-1,0,1,2])

x = np.linspace(-5, 5, 20)
y = np.linspace(-5, 5, 20)


plt.subplot(2, 3, 3) # bottom left
X, Y = np.meshgrid(x, y)
Z = X**2 + Y**2 


plt.contourf(X, Y, Z, levels=20, cmap='Reds')
plt.colorbar()

plt.subplot(2, 3, 4)
Z2 = X**2 - y**2

plt.contourf(X, Y, Z, levels=20)
plt.colorbar()

plt.savefig('matplotlib_example.jpg')

plt.show()

# %%
x = np.linspace(1/(2*math.e), math.e**2+1, 100)

plt.figure()
plt.plot(x, np.log(x))
plt.title('ln(x)')
plt.show()

#plt.figure()
plt.plot(x, np.log(1/x))
plt.title('$\\ln(\\frac{1}{x})$')

plt.show()

# %% [markdown]
# ### Histogram

# %%
h = np.random.normal(1, 2, 1000)

plt.subplot(1,2,1)
n, bins, patches = plt.hist(h, bins=30)

plt.subplot(1, 2, 2)
plt.hist(h, bins=20, histtype='bar', edgecolor='k', density=True)
plt.suptitle('Histogram')
plt.show()

# %%
x = np.random.normal(0,2,100)
y = np.random.normal(0,2,100)

plt.figure()
plt.hist2d(x, y, bins=(20, 30), cmap='BuGn')
plt.colorbar()
plt.title('hist2d plot')

plt.figure()
plt.hexbin(x, y,bins=20, gridsize=20, extent=(-5, 5, -5, 5), cmap='Reds')
plt.colorbar()
plt.title('hexbin plot')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

x = np.arange(-4, 4,0.1)
y = np.arange(-4, 4,0.2)
X, Y = np.meshgrid(x, y)
Z=np.sin(X)+np.cos(Y)
#Z[Z<X+Y]=-8
Z2=X+Y
#Z2[Z>X+Y]=-8

fig = plt.figure()
ax = fig.gca(projection='3d')
ax.view_init(45, -48)
ax.plot_wireframe(X,Y,Z2)
#ax.plot_surface(X, Y, Z, cmap='plasma')
#ax.plot_surface(X,Y,Z2)
ax.plot_wireframe(X, Y, Z, cmap='plasma')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('$\sin(x)+\cos(y)$')
plt.show()

# %%
help(ax.plot_surface)
# Out:
# Help on method plot_surface in module mpl_toolkits.mplot3d.axes3d:
#
# plot_surface(X, Y, Z, *args, norm=None, vmin=None, vmax=None, lightsource=None, **kwargs) method of matplotlib.axes._subplots.Axes3DSubplot instance
#     Create a surface plot.
#
#     By default it will be colored in shades of a solid color, but it also
#     supports color mapping by supplying the *cmap* argument.
#
#     .. note::
#
#        The *rcount* and *ccount* kwargs, which both default to 50,
#        determine the maximum number of samples used in each direction.  If
#        the input data is larger, it will be downsampled (by slicing) to
#        these numbers of points.
#
#     .. note::
#
#        To maximize rendering speed consider setting *rstride* and *cstride*
#        to divisors of the number of rows minus 1 and columns minus 1
#        respectively. For example, given 51 rows rstride can be any of the
#        divisors of 50.
#
# ...

# %%
Fi=np.linspace(0,2*np.pi,100)
r=np.sin(Fi+np.pi)
plt.polar(Fi, r, 'r-')
